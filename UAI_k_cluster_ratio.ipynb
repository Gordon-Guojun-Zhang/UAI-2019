# %% [markdown]
# ## Comparing EM with GD

# %% [markdown]
# ### First, we set up by choosing the number of clusters $m$, the number of features $n$, and generate samples by use of a BMM with random parameters. The goal is to recover this setting. The sample set is $S$, which is a dictionary containing binary strings $x$. Notice that replicates are gathered together to save space.

# %%
import nbm
import numpy as np
m = 2  # number of classes
n = 5 # number of features
samples = 1000000 # sample size
# generate the parameters
[gtheta, gPhi] = nbm.randInt(m, n)
total = np.zeros(n)
ct = 0
# generate samples
S = dict()
for _ in range(2**n):    # the sample space
# compute the probability
    x = nbm.decToBits(_, n)   # convert decimal to binary
    prob = 0.0
    for __ in range(m):
        prob += gtheta[__] * nbm.bern_n(x, gPhi[__, :], n) 
    S[_] = prob * samples
# add to the dictionary
avg = np.zeros(n)
for __ in range(m):
    avg += gtheta[__] *gPhi[__, :]
diff = gPhi[1, :] - gPhi[0, :]
Sigma = np.multiply(avg, 1 - avg)

# %%
print("gtheta: ", gtheta)
print("gPhi: ", gPhi)
# Out:
# gtheta:  [0.193 0.807]
# gPhi:  [[0.0191 0.0789 0.8774 0.2741 0.2515]
#  [0.4478 0.7046 0.3388 0.2343 0.0886]]

# %% [markdown]
# ### Checking if EM can converge to a k-cluster point, which we call "bad min"

# %%
# initialize params
print("-------------------EM: ----------------------------")
bad_min = 0
for _ in range(60):
    print("-----------------------iteration: ", _, "-----------------------------")
    [theta, Phi] = nbm.randInt(m, n)
    Phi = np.random.rand(m, n)
    [theta1, Phi1] = nbm.em(n, m, samples, S, theta, Phi)
    if min(theta1) < 0.0005:
        print("bad min!")
        print("theta1: ", theta1)
        bad_min += 1
    else:
        print("nice!")
print("bad_min: ", bad_min)
# Out:
# -------------------EM: ----------------------------
# -----------------------iteration:  0 -----------------------------
# nice!
# -----------------------iteration:  1 -----------------------------
# nice!
# -----------------------iteration:  2 -----------------------------
# nice!
# -----------------------iteration:  3 -----------------------------
# nice!
# -----------------------iteration:  4 -----------------------------
# nice!
# -----------------------iteration:  5 -----------------------------
# nice!
# -----------------------iteration:  6 -----------------------------
# nice!
# -----------------------iteration:  7 -----------------------------
# nice!
# -----------------------iteration:  8 -----------------------------
# nice!
# -----------------------iteration:  9 -----------------------------
# nice!
# -----------------------iteration:  10 -----------------------------
# nice!
# -----------------------iteration:  11 -----------------------------
# nice!
# -----------------------iteration:  12 -----------------------------
# nice!
# -----------------------iteration:  13 -----------------------------
# nice!
# -----------------------iteration:  14 -----------------------------
# nice!
# -----------------------iteration:  15 -----------------------------
# nice!
# -----------------------iteration:  16 -----------------------------
# nice!
# -----------------------iteration:  17 -----------------------------
# nice!
# -----------------------iteration:  18 -----------------------------
# nice!
# -----------------------iteration:  19 -----------------------------
# nice!
# -----------------------iteration:  20 -----------------------------
# nice!
# -----------------------iteration:  21 -----------------------------
# nice!
# -----------------------iteration:  22 -----------------------------
# nice!
# -----------------------iteration:  23 -----------------------------
# nice!
# -----------------------iteration:  24 -----------------------------
# nice!
# -----------------------iteration:  25 -----------------------------
# nice!
# -----------------------iteration:  26 -----------------------------
# nice!
# -----------------------iteration:  27 -----------------------------
# nice!
# -----------------------iteration:  28 -----------------------------
# nice!
# -----------------------iteration:  29 -----------------------------
# nice!
# -----------------------iteration:  30 -----------------------------
# nice!
# -----------------------iteration:  31 -----------------------------
# nice!
# -----------------------iteration:  32 -----------------------------
# nice!
# -----------------------iteration:  33 -----------------------------
# nice!
# -----------------------iteration:  34 -----------------------------
# nice!
# -----------------------iteration:  35 -----------------------------
# nice!
# -----------------------iteration:  36 -----------------------------
# nice!
# -----------------------iteration:  37 -----------------------------
# nice!
# -----------------------iteration:  38 -----------------------------
# nice!
# -----------------------iteration:  39 -----------------------------
# nice!
# -----------------------iteration:  40 -----------------------------
# nice!
# -----------------------iteration:  41 -----------------------------
# nice!
# -----------------------iteration:  42 -----------------------------
# nice!
# -----------------------iteration:  43 -----------------------------
# nice!
# -----------------------iteration:  44 -----------------------------
# nice!
# -----------------------iteration:  45 -----------------------------
# nice!
# -----------------------iteration:  46 -----------------------------
# nice!
# -----------------------iteration:  47 -----------------------------
# nice!
# -----------------------iteration:  48 -----------------------------
# nice!
# -----------------------iteration:  49 -----------------------------
# nice!
# -----------------------iteration:  50 -----------------------------
# nice!
# -----------------------iteration:  51 -----------------------------
# nice!
# -----------------------iteration:  52 -----------------------------
# nice!
# -----------------------iteration:  53 -----------------------------
# nice!
# -----------------------iteration:  54 -----------------------------
# nice!
# -----------------------iteration:  55 -----------------------------
# nice!
# -----------------------iteration:  56 -----------------------------
# nice!
# -----------------------iteration:  57 -----------------------------
# nice!
# -----------------------iteration:  58 -----------------------------
# nice!
# -----------------------iteration:  59 -----------------------------
# nice!
# bad_min:  0

# %% [markdown]
# ### Checking if GD can converge to a k-cluster point, which we call "bad min"

# %%
print("-------------------GD: ----------------------------")
bad_min = 0
for _ in range(60):
    print("-----------------------iteration: ", _, "-----------------------------")
    [theta, Phi] = nbm.randInt(m, n)
    [ell, theta, Phi, iterId] = nbm.gradientDescent(n, samples, S, theta, Phi, numIterations=10000, alpha = 0.02, tolerance = 1e-7)
#    print("final ell: ", ell)
    if min(theta) < 0.0005:
        print("bad min!")
        print("final theta: ", theta)
        bad_min += 1
    else:
        print("nice!")
print("bad_min: ", bad_min)
# Out:
# -------------------GD: ----------------------------
# -----------------------iteration:  0 -----------------------------
# GD converges at  5571 steps
# nice!
# -----------------------iteration:  1 -----------------------------
# GD converges at  5355 steps
# nice!
# -----------------------iteration:  2 -----------------------------
# GD converges at  6020 steps
# nice!
# -----------------------iteration:  3 -----------------------------
# GD converges at  210 steps
# bad min!
# final theta:  [1. 0.]
# -----------------------iteration:  4 -----------------------------
# GD converges at  149 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  5 -----------------------------
# GD converges at  5586 steps
# nice!
# -----------------------iteration:  6 -----------------------------
# GD converges at  5641 steps
# nice!
# -----------------------iteration:  7 -----------------------------
# GD converges at  142 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  8 -----------------------------
# GD converges at  6643 steps
# nice!
# -----------------------iteration:  9 -----------------------------
# GD converges at  8954 steps
# nice!
# -----------------------iteration:  10 -----------------------------
# GD converges at  6771 steps
# nice!
# -----------------------iteration:  11 -----------------------------
# GD converges at  5430 steps
# nice!
# -----------------------iteration:  12 -----------------------------
# GD converges at  5998 steps
# nice!
# -----------------------iteration:  13 -----------------------------
# GD converges at  4097 steps
# nice!
# -----------------------iteration:  14 -----------------------------
# GD converges at  141 steps
# bad min!
# final theta:  [1. 0.]
# -----------------------iteration:  15 -----------------------------
# GD converges at  5088 steps
# nice!
# -----------------------iteration:  16 -----------------------------
# GD converges at  6786 steps
# nice!
# -----------------------iteration:  17 -----------------------------
# GD converges at  6973 steps
# nice!
# -----------------------iteration:  18 -----------------------------
# GD converges at  5918 steps
# nice!
# -----------------------iteration:  19 -----------------------------
# GD converges at  6476 steps
# nice!
# -----------------------iteration:  20 -----------------------------
# GD converges at  7234 steps
# nice!
# -----------------------iteration:  21 -----------------------------
# GD converges at  6289 steps
# nice!
# -----------------------iteration:  22 -----------------------------
# GD converges at  151 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  23 -----------------------------
# GD converges at  4249 steps
# nice!
# -----------------------iteration:  24 -----------------------------
# GD converges at  4968 steps
# nice!
# -----------------------iteration:  25 -----------------------------
# GD converges at  6688 steps
# nice!
# -----------------------iteration:  26 -----------------------------
# GD converges at  5905 steps
# nice!
# -----------------------iteration:  27 -----------------------------
# GD converges at  7923 steps
# nice!
# -----------------------iteration:  28 -----------------------------
# GD converges at  5012 steps
# nice!
# -----------------------iteration:  29 -----------------------------
# GD converges at  6420 steps
# nice!
# -----------------------iteration:  30 -----------------------------
# GD converges at  4949 steps
# nice!
# -----------------------iteration:  31 -----------------------------
# GD converges at  150 steps
# bad min!
# final theta:  [1. 0.]
# -----------------------iteration:  32 -----------------------------
# GD converges at  4772 steps
# nice!
# -----------------------iteration:  33 -----------------------------
# GD converges at  140 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  34 -----------------------------
# GD converges at  7251 steps
# nice!
# -----------------------iteration:  35 -----------------------------
# GD converges at  6366 steps
# nice!
# -----------------------iteration:  36 -----------------------------
# GD converges at  5722 steps
# nice!
# -----------------------iteration:  37 -----------------------------
# GD converges at  349 steps
# bad min!
# final theta:  [1. 0.]
# -----------------------iteration:  38 -----------------------------
# GD converges at  6413 steps
# nice!
# -----------------------iteration:  39 -----------------------------
# GD converges at  6412 steps
# nice!
# -----------------------iteration:  40 -----------------------------
# GD converges at  248 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  41 -----------------------------
# GD converges at  5343 steps
# nice!
# -----------------------iteration:  42 -----------------------------
# GD converges at  3524 steps
# nice!
# -----------------------iteration:  43 -----------------------------
# GD converges at  6179 steps
# nice!
# -----------------------iteration:  44 -----------------------------
# GD converges at  6359 steps
# nice!
# -----------------------iteration:  45 -----------------------------
# GD converges at  5453 steps
# nice!
# -----------------------iteration:  46 -----------------------------
# GD converges at  220 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  47 -----------------------------
# GD converges at  9100 steps
# nice!
# -----------------------iteration:  48 -----------------------------
# GD converges at  5410 steps
# nice!
# -----------------------iteration:  49 -----------------------------
# GD converges at  5415 steps
# nice!
# -----------------------iteration:  50 -----------------------------
# GD converges at  5745 steps
# nice!
# -----------------------iteration:  51 -----------------------------
# GD converges at  5991 steps
# nice!
# -----------------------iteration:  52 -----------------------------
# GD converges at  199 steps
# bad min!
# final theta:  [0. 1.]
# -----------------------iteration:  53 -----------------------------
# GD converges at  6312 steps
# nice!
# -----------------------iteration:  54 -----------------------------
# GD converges at  5941 steps
# nice!
# -----------------------iteration:  55 -----------------------------
# GD converges at  4437 steps
# nice!
# -----------------------iteration:  56 -----------------------------
# GD converges at  5627 steps
# nice!
# -----------------------iteration:  57 -----------------------------
# GD converges at  2201 steps
# nice!
# -----------------------iteration:  58 -----------------------------
# GD converges at  6987 steps
# nice!
# -----------------------iteration:  59 -----------------------------
# GD converges at  201 steps
# bad min!
# final theta:  [1. 0.]
# bad_min:  12
